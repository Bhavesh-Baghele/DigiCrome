# %%
3+5 # addition
# Out:
# 8

# %%
8
# Out:
# 8

# %%
6
# Out:
# 6

# %%
6
# Out:
# 6

# %% [markdown]
# # k
# ## k
# ### k

# %%
pwd    # shows the path
# Out:
# 'E:\\AI and Data Science\\Python'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
4**2  #Exponential
# Out:
# 16

# %%
8**3
# Out:
# 512

# %%
7*6
# Out:
# 42

# %% [markdown]
# # Hello

# %% [markdown]
# # Hello

# %% [markdown]
# # M

# %%
# M for markdown
# Y for coding cell

# %% [markdown]
# # Hello

# %%
# just select - green(editing)
# just  selected cell - blue(selected cell)

# %%
# To delete - DD
# Undo - Z

# %% [markdown]
# # hello

# %%
`Hello`
# Out:
#   Input In [6]
#     `Hello`
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# `hello`

# %%
# to highlight use `(back quote)

# %% [markdown]
# `v`

# %% [markdown]
# # hello
# * point

# %% [markdown]
# # hi
# *pt
#     *pt
#         *pt
#             *pt

# %% [markdown]
# #### gh
# * h
# * j
#     * h
#         * h

# %% [markdown]
# ### gft
# * 1
# * 2
#     * 1
#     * 2
#         * 1
#         * 2
#             * 1
#             * 2
#             * 3

# %% [markdown]
# # hi
# *pt

# %% [markdown]
# # hi
# * point

# %% [markdown]
# # hi
# * pt
#     * pt
#         * pt
#             * pt

# %% [markdown]
# ## hi
# * pt
#     * pt
#         * pt
#             * pt

# %% [markdown]
# ## SUB HEAD
# 1. Hello
# 2. HI
#     1. Hello
#     2. Hi
#         1. HI
#         2. Hello
#             1. Hi
#             2. Hello
#                 1. HI
#                 2. Hello

# %% [markdown]
# #### fdgh
# 1. f
# 2. vg
#     1. fg
#     2. bg
#         1. yt
#         2. gf
#             1. bg
#             2. bg
#                 1. ghj
#                 2. fgtr

# %% [markdown]
# ### SUB HEAD
# 1. Hello
# 2. HI
#     1. Hello
#     2. Hi
#         1. HI
#         2. Hello
#             1. Hi
#             2. Hello
#                 1. HI
#                 2. Hello

# %% [markdown]
# $hello$

# %% [markdown]
# type(0)

# %%
type(3.3)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
type("""hello""")
# Out:
# str

# %%
type('hello')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
# t not equals to T
# Python read top to bottom, left to right

# %%
23
34
45 # output of last value
# Out:
# 45

# %%
"34" #text str
# Out:
# '34'

# %%
print("34")
print(23)
print(34)
print(45)
1234
# Out:
# 34
# 23
# 34
# 45
# 1234

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Variable

# %%
# assignment operator =
x=10  #  10---> x

# %%
print(x)
# Out:
# 10

# %%
a  # a is not known to python 
a=10 # top to bottom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 a  # a is not known to python
#       2 a=10
#
# NameError: name 'a' is not defined

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
print("a")
# Out:
# a

# %%
a=10
print("a")
# Out:
# a

# %%
print(a)
# Out:
# 10

# %%
r=9
r
# Out:
# 9

# %% [markdown]
# ## Limitation of variable

# %% [markdown]
# 1. cant start with a number

# %% [markdown]
# 2. cant give space
# 3. no symbol

# %%
2abc=10
# Out:
#   Input In [29]
#     2abc=10
#      ^
# SyntaxError: invalid syntax

# %%
a b c=10
# Out:
#   Input In [30]
#     a b c=10
#       ^
# SyntaxError: invalid syntax

# %%
a$b$c
# Out:
#   Input In [31]
#     a$b$c
#      ^
# SyntaxError: invalid syntax

# %%
a_b_c=10

# %%
a_b_c =10

# %%
*abc=10
# Out:
#   Input In [35]
#     *abc=10
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
abc* =10
# Out:
#   Input In [36]
#     abc* =10
#          ^
# SyntaxError: invalid syntax

# %%
abc*=10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 abc*=10
#
# NameError: name 'abc' is not defined

# %%
5//3   # // will not give decimal output
# Out:
# 1

# %% [markdown]
# PEMDAS
# P - () Paranthesis
# E - ** Exponential
# M,D,A,S- Mul div add sub - which ever comes first

# %% [markdown]
# ### String Operations

# %%
a="qwerty"
  # 0123456  6-1  ,n-1

# %%
# indexing
a[0]
# Out:
# 'q'

# %%
a[2]
# Out:
# 'e'

# %%
a[6]  # string out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 a[6]
#
# IndexError: string index out of range

# %%
a[5]
# Out:
# 'y'

# %%
a[-1]
# Out:
# 'y'

# %%
a[-4]
# Out:
# 'e'

# %% [markdown]
# ### $SLICING$

# %%
a="qwerty"
a
# Out:
# 'qwerty'

# %%
a[:]
# Out:
# 'qwerty'

# %%
a[4]
# Out:
# 't'

# %%
a[2:4]
# Out:
# 'er'

# %%
a[:4] # why not t , n-1.... higher-1 index
# Out:
# 'qwer'

# %%
a[:5]
# Out:
# 'qwert'

# %%
a[1:5]  # lower is included but higher is not
# Out:
# 'wert'

# %%
a
# Out:
# 'qwerty'

# %%
a[:-1]
# Out:
# 'qwert'

# %%
a[-3:-1]  #a[-1:-3] no becz it read left to right
# Out:
# 'rt'

# %%
a[-4:5]  #code reading from left to right
# Out:
# 'ert'

# %%
a
# Out:
# 'qwerty'

# %%
a[2]
# Out:
# 'e'

# %%
a[-4:2]
# Out:
# ''

# %%
a[-2:2] #not able to read, becz left to right
# Out:
# ''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=5

# %%
a = 5

# %%
a * 1
# Out:
# 5

# %% [markdown]
# # -ve

# %%
a
# Out:
# 5

# %%
a = "qwerty"
a
# Out:
# 'qwerty'

# %%
a[:-1]
# Out:
# 'qwert'

# %%
a[-3:-1] #a[-1:-3] no becz it read left to right
# Out:
# 'rt'

# %%
a[-4:5] # code reading from left to right
# Out:
# 'ert'

# %%
a
# Out:
# 'qwerty'

# %%
a[2]
# Out:
# 'e'

# %%
a[-4:2]
# Out:
# ''

# %%
a[-2:2] # not able to read, becz right to left
# Out:
# ''

# %%
a
# Out:
# 'qwerty'

# %%
a[::-1]
# Out:
# 'ytrewq'

# %%
a[::-2]  # step / jump
# Out:
# 'yrw'

# %%
b="abcdefghijklmnopqrstuvwxyz"
b[::-5]
# Out:
# 'zupkfa'

# %%
b[::5]
# Out:
# 'afkpuz'

# %%
b[10:1:1]
# Out:
# ''

# %%
b[10:1:-1]
# Out:
# 'kjihgfedc'

# %%
b[10:1:-2]
# Out:
# 'kigec'

# %%
b[-1:-10:-2]
# Out:
# 'zxvtr'

# %%
a
# Out:
# 'qwerty'

# %%
a[::-1]
# Out:
# 'ytrewq'

# %%
a[0]="Q" # not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 a[0]="Q"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Functions of strings

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"HELLO".lower()
# Out:
# 'hello'

# %%
"hello hi".title()
# Out:
# 'Hello Hi'

# %%
"hello sam how r u".capitalize()
# Out:
# 'Hello sam how r u'

# %%
"hello sam how r u".endswith("u")
# Out:
# True

# %%
"hello sam how r u".endswith("m")
# Out:
# False

# %%
"hello sam how r u".replace("h","H")
# Out:
# 'Hello sam How r u'

# %%
"hello sam how r u".find("r")
# Out:
# 14

# %%
"hello sam how r u".find("how")
# Out:
# 10

# %%
"hello Sam How r u".swapcase()
# Out:
# 'HELLO sAM hOW R U'

# %% [markdown]
# ## Basic print

# %%
"hello"
# Out:
# 'hello'

# %%
h="hello"
h
# Out:
# 'hello'

# %%
q="quaity"
q
# Out:
# 'quaity'

# %%
h
q
# Out:
# 'quaity'

# %%
print(h)
print(q)
# Out:
# hello
# quaity

# %%
print("hello")
# Out:
# hello

# %%
name="SAM"
print("hello",name) #mind comma
# Out:
# hello SAM

# %% [markdown]
# Dynamic Typing
#
# Python is case sensitive T not equals to t
# python read code from top to bottom
# python reads from left to right

# %%
a=2
print(type(a),"Value in a=",a)
a=2.4
print(type(a),"Value in a=",a)
a=True
print(type(a),"Value in a=",a)
a="Hello"
print(type(a),"Value in a=",a)
# Out:
# <class 'int'> Value in a= 2
# <class 'float'> Value in a= 2.4
# <class 'bool'> Value in a= True
# <class 'str'> Value in a= Hello

# %% [markdown]
# ### Print Method

# %%
a=100
b="price is ="
print("Product",b,a)
# Out:
# Product price is = 100

# %%
# que
name="Sam"
city="qwert"
"hello i am",name,"and i live in CITY"
# Out:
# ('hello i am', 'Sam', 'and i live in CITY')

# %%
print("Hello i am",name,"and i live in",city)
# Out:
# Hello i am Sam and i live in qwert

# %% [markdown]
# print("hi)  #SyntaxError

# %% [markdown]
# ## Next Line

# %%
print("hello hi")
print("hello\nhi")
print("-----------")
print("hello \n\n\n\n\n hi")   # \n is for new line
# Out:
# hello hi
# hello
# hi
# -----------
# hello
#
#
#
#
#  hi

# %%
print("hello","Hi","!!!")
# Out:
# hello Hi !!!

# %%
print("hello","Hi","!!!",sep="")
print("hello","Hi","!!!",sep="_*_")
# Out:
# helloHi!!!
# hello_*_Hi_*_!!!

# %%
print("hello Sam")
print("How are you")
# Out:
# hello Sam
# How are you

# %%
print("hello","Hi","!!!",sep="Good Morning")  # seperator replaces the space
print("hello","Hi","!!!",sep="_*_")
# Out:
# helloGood MorningHiGood Morning!!!
# hello_*_Hi_*_!!!

# %%
print("hello Sam\n",end="")
print("How are you")
# Out:
# hello Sam
# How are you

# %%
print("hello Sam",end="   ")
print("How are you")
# Out:
# hello Sam   How are you

# %%
print("hello Sam",end="!!!! \n")
print("How are you")
# Out:
# hello Sam!!!!
# How are you

# %%
a="alpha"
print("best wolf is",a,"wolf",end="**** \n")
print("Cheetah","is","fastest",sep="$")
# Out:
# best wolf is alpha wolf****
# Cheetah$is$fastest

# %%
a="alpha"
print("best wolf is",a,"wolf",end="**** ")
print("Cheetah","is","fastest",sep="$")
# Out:
# best wolf is alpha wolf**** Cheetah$is$fastest

# %%
a="alpha"
print("best wolf is",a,"wolf",end="****\n\n")
print("Cheetah","is","fastest",sep="$")
# Out:
# best wolf is alpha wolf****
#
# Cheetah$is$fastest

# %%
a="Sam"
b="Newyork"
print("Hi my name is",a,"I live in",b)
# Out:
# Hi my name is Sam I live in Newyork

# %%
print("Hi my name is {} I live in {}".format(a,b))
# Out:
# Hi my name is Sam I live in Newyork

# %%
c=100
print("Hi my name is {2} I live in {1} {0}".format(a,b,c))
# Out:
# Hi my name is 100 I live in Newyork Sam

# %%
print(f"Hi my name is {a} I live in {b}")
# Out:
# Hi my name is Sam I live in Newyork

# %% [markdown]
# ### Que
#
# print statement by f format
#
# hello my name is NAME my Age is AGE and my Experience is EXP

# %%
a = "BHAVESH"
b= 31
c = 7

print(f"hello my name is {a} my Age is {b} and my Experience is {c} years")
# Out:
# hello my name is BHAVESH my Age is 31 and my Experience is 7 years

# %%
a = "BHAVESH"
b= "31 years"
c = 7

print(f"hello my name is {a} my Age is {b} and my Experience is {c} years")
# Out:
# hello my name is BHAVESH my Age is 31 years and my Experience is 7 years

# %% [markdown]
# ### INPUT

# %%
input()
# Out:
# k
# 'k'

# %%
input("Name\n Plz= ")
# Out:
# Name
#  Plz= Sam
# 'Sam'

# %%
a=input()
a
# Out:
# sam
# 'sam'

# %%
a=input()
a
# Out:
# sam
# 'sam'

# %%
a=input()
a
# Out:
# 12345
# '12345'

# %%
type(a)
# Out:
# str

# %%
a=input()
# Out:
# 12345

# %%
a=input()
a
# Out:
# 12345
# '12345'

# %%
a
# Out:
# '12345'

# %%
a=input()
a
# Out:
# sam
# 'sam'

# %%
type("123456")
# Out:
# str

# %%
type(12345)
# Out:
# int

# %% [markdown]
# ### input is by default STR

# %%
# que
# Add 2 value
a=input("a= ")
b=input("b= ")
print("the a+b result is",a+b)
# Out:
# a= 3
# b= 4
# the a+b result is 34

# %%
"hello"+" "+"SAM"
# Out:
# 'hello SAM'

# %%
v=int("3")
type(v)
# Out:
# int

# %% [markdown]
# ### Resolving issue of int

# %%
a=input("a= ")
b=input("b= ")
a=int(a)
b=int(b)
print("the a+b result is",a+b)
# Out:
# a= 3
# b= 4
# the a+b result is 7

# %%
int("abc")  # Only a number can be a input
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
a=int(input("a= "))
b=int(input("b= "))

print("the a+b result is",a+b)
# Out:
# a= 3
# b= 4
# the a+b result is 7

# %% [markdown]
# #### Some Good Points to know

# %%
name=input("name= ")
fix_salary=int(input("fix_salary= "))
variable_salary=int(input("variable_salary= "))

print(name ,"total salary is",fix_salary+variable_salary)
# Out:
# name= Bhavesh
# fix_salary= 200000
# variable_salary= 3500
# Bhavesh total salary is 203500

# %% [markdown]
# ### Some Good to know points

# %%
a,b,c=2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 2 3
# 3 2

# %%
a=b=c=4

# %%
print(a,b,c)
# Out:
# 4 4 4
